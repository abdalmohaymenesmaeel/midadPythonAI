# %%
def y():
    def x():
        print("x")
    x()
y()
# Out:
# x

# %%
def x():
    return 100
def z():
    return x()
z()
# Out:
# 100

# %%
def y():
    t=10
    def x():
        t=100
        print(t)
    x()
    print(t)
    
y()
# Out:
# 100
# 10

# %%
def y():
    t=10
    def x():
        nonlocal t
        t+=100
        print(t)
    x()
    print(t)
    
y()
# Out:
# 110
# 110

# %%
#local
#global
#nonlocal nested function

# %%
def y():
    t=10
    def x():
        nonlocal t
        t=100
        print(t)
    x()
    print(t)

y()
# Out:
# 100
# 100

# %%
#closures

# %%
msg="abd"
def inner():
    global msg
    msg="hamza"
    print(msg)
inner()
# Out:
# hamza

# %%
print(msg)
# Out:
# hamza

# %%
def outer():
    msg="abdalmohaymen"
    def inner():
        nonlocal msg
        msg="Ghaith"
        print(msg)
    return inner

# %%
closer=outer()
closer()
# Out:
# Ghaith

# %%
c=0
def counter():
    global c
    c+=1
counter()
counter()
counter()

# %%
c
# Out:
# 3

# %%
def outer():
    c1=0
    def counter():
        nonlocal c1
        c1+=1
        print(c1)
    return counter

# %%
closer1=outer()

# %%
closer1()
# Out:
# 1

# %%
closer1()
# Out:
# 2

# %%
closer1()
# Out:
# 3

# %%
closer1()
# Out:
# 4

# %%
print(c1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 print(c1)
#
# NameError: name 'c1' is not defined

# %%
def multiplier(factor):
    def multiply_by(number):
        return number*factor
    return multiply_by

# %%
double=multiplier(2)
double(5)
double(20)
# Out:
# 40

# %%
triple=multiplier(3)
triple(5)
# Out:
# 15

# %% [markdown]
# def multiply_by(number):
#     return number*2

# %%
#function+global vairables in same block

# %%
#lambda Expression

# %%
def sumNumbers(x,y):
    return x+y
sumNumbers(10,20)
# Out:
# 30

# %%
sumNumbersLambda=lambda x,y:x+y
sumNumbersLambda(10,20)
# Out:
# 30

# %%
def power(n):
    return n**2
u=lambda x,p:x**p

# %%
lst=[10,20,30,40]
lst1=list(map(lambda x:x**4,lst))
lst1
# Out:
# [10000, 160000, 810000, 2560000]

# %%
lst=[10,20,30,40,15,22,33]

def checkEven(n):
    return n%2==0
lst1=list(filter(checkEven,lst))
lst1
# Out:
# [10, 20, 30, 40, 22]

# %%
lst2=list(filter(lambda n:n%2==0,lst))
lst2
# Out:
# [10, 20, 30, 40, 22]

# %%
nested functions
nonlocal
closers
lambda expression
