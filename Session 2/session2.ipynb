# %%
x=20
citizon=True

# %%
if x>=18:
    if citizon==True:
        print("Elegable to vote")
# Out:
# Elegable to vote

# %%
if x>=18 and  citizon==True:
    print("Elegable to vote")
# Out:
# Elegable to vote

# %%
n1=10
n2=5
n3=3
if n1>n2 >n3:
    print("Welcome")
# Out:
# Welcome

# %%
n1=10
n2=5
n3=3
if n1>n2 and n2 >n3:
    print("Welcome")
# Out:
# Welcome

# %%
name=None
if not(name):
    print("Hello")
else:
    print("Welcome in our session")
# Out:
# Hello

# %%
name="Abd almohaymen"
if not(name):
    print("Hello")
else:
    print("Welcome in our session")
# Out:
# Welcome in our session

# %%
name="Abd almohaymen"
if not(name==True):
    print("Hello")
else:
    print("Welcome in our session")
# Out:
# Hello

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
#write code for calculate circle area
#radius input > 0

# %%
radius=float(input("Enter Radius:"))
# Out:
# Enter Radius: 5

# %%
if radius>0:
    area=radius*radius*3.14
else:
    print("Invalid Radius Value")

# %%
radius**2
# Out:
# 25.0

# %%
radius*radius
# Out:
# 25.0

# %%
u=""

# %%
#failed
#good
#very good
#excellent
#honer

# %%
mark=int(input("Enter Your Mark"))
if mark >=0 and mark <=100:
    # 0 100
    if mark <=59:
        print("Failed")
    elif  mark<=69:
        print("good")
    elif mark<=79:
        print("very good")
    elif mark<=89:
        print("Excellent")
    else:
        print("Honer")
else:
    print("Invalid mark")
# Out:
# Enter Your Mark 95
# Honer

# %%
string="Welcome in our session"
if "our" in string:
    print("Exist")
else:
    print("not exist")

#implicit loop
# Out:
# Exist

# %%
Expression #single line
Statment # multi line

# %%
x=9

# %%
if x%2==0:
    print("even")
else:
    print("odd")
# Out:
# odd

# %%
res=""
if x%2==0:
    res="even"
else:
    res="odd"

# %%
res
# Out:
# 'odd'

# %%
#بنى التحكم
#بنى التحكم الشرطية
#بنى التحكم التكرارية

# %%
result= "even" if x%2==0  else "odd"

# %%
result
# Out:
# 'odd'
