# %%
#age 40 year

# %%
text="age 40 year 55 a"
number=""
prev=0
lst=[]
for i in text:
    if i.isdigit():
        prev=1
        number+=i
    else:
        if prev==1:
            lst.append(number)
            number=""
        prev=0
print(lst)
# Out:
# ['40', '55']

# %%
import re 
match=re.findall(r'\d+',text)
print(match)
# Out:
# ['40', '55']

# %%
text="Hello, world"
pattern=r"^Hello"
re.match(pattern,text)
# Out:
# <re.Match object; span=(0, 5), match='Hello'>

# %%
text="Hello world"
pattern=r"world$"
re.search(pattern,text)
# Out:
# <re.Match object; span=(6, 11), match='world'>

# %%
text="my phone number is 12345"
numbers=re.findall(r"\d",text)
numbers
# Out:
# ['1', '2', '3', '4', '5']

# %%
text="my phone number is 12345 in our 76575"
numbers=re.findall(r"\d+",text)
numbers
# Out:
# ['12345', '76575']

# %%
text="my phone number is 12345 in our 76575 kjg 9876543"
numbers=re.findall(r"\d{5}",text)
numbers
# Out:
# ['12345', '76575', '98765']

# %%
text="my phone number is 12345 in our 76575 kjg 9876543"
numbers=re.search(r"\d{5}",text)
numbers.group()
# Out:
# '12345'

# %%
text="my phone number is 12345 in our 76575 kjg 9876543"
strings=re.findall(r"[0-9]+",text)
strings
# Out:
# ['12345', '76575', '9876543']

# %%
newstr=" ".join(strings)
newstr
# Out:
# '12345 76575 9876543'

# %%
text="(0959456567"
strings=re.findall(r"[0-9]{10}+",text)
strings
# Out:
# ['0959456567']

# %%
text="0959456567"
matched=re.match(r"^[0-9]{10}$",text)
if matched:
    print("Valid phone number")
else:
    print("not valid")
# Out:
# Valid phone number

# %%
text="Welcome in our Session"
newText=re.sub(r"\s","-",text)
newText
# Out:
# 'Welcome-in-our-Session'

# %%
text="Welcome in our Session9876"
newText=re.sub(r"\d+"," ",text)
newText
# Out:
# 'Welcome in our Session '

# %%
text="Haider HassouN"
letters=re.findall(r"[a-z]",text)
letters
# Out:
# ['a', 'i', 'd', 'e', 'r', 'a', 's', 's', 'o', 'u']

# %%
text="Haider HassouN yyttT"
letters=re.findall(r"[a-z]+",text)
letters
# Out:
# ['aider', 'assou', 'yytt']

# %%
days="sat sun mon tus wed the fri"
words=re.split(r"\W+",days)
words
# Out:
# ['sat', 'sun', 'mon', 'tus', 'wed', 'the', 'fri']

# %%
days="sat  sun    mon    tus wed the fri"
words=re.split(r"\W+",days)
words
# Out:
# ['sat', 'sun', 'mon', 'tus', 'wed', 'the', 'fri']

# %%
days="sat  sun    mon    tus wed the fri"
words=re.split(r" ",days)
words
# Out:
# ['sat', '', 'sun', '', '', '', 'mon', '', '', '', 'tus', 'wed', 'the', 'fri']

# %%
days.split(" ")
# Out:
# ['sat', '', 'sun', '', '', '', 'mon', '', '', '', 'tus', 'wed', 'the', 'fri']
