# %%
x=10

# %%
z=20

# %%
y=x+z
y
# Out:
# 30

# %%
print(y*2)
# Out:
# 60

# %%
5+2
# Out:
# 7

# %%
5-2
# Out:
# 3

# %%
5*2
# Out:
# 10

# %%
4/2
# Out:
# 2.0

# %%
4==4
# Out:
# True

# %%
4!=4
# Out:
# False

# %%
4>4
# Out:
# False

# %%
4<=4
# Out:
# True

# %%
2**5
# Out:
# 32

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10//3
# Out:
# 3

# %%
10%3
# Out:
# 1

# %%
True or True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
not(False and False)
# Out:
# True

# %%
x=10

# %%
x=5

# %%
print(x)
# Out:
# 5

# %%
print("Welcome in our session",end=' ')
print("Welcome in our session")
# Out:
# Welcome in our session Welcome in our session

# %%
name=input()
# Out:
#  Helllo

# %%
print(name)
# Out:
# Helllo

# %%
num1=int(input("Enter Number 1:"))
num2=int(input("Enter Number 2:"))
# Out:
# Enter Number 1: 22
# Enter Number 2: 15

# %% [markdown]
# num1=int(num1)
# num2=int(num2)

# %%
print(num1+num2)
# Out:
# 37

# %%
birthDate=int(input("Enter Birth Year"))
name=input("Enter your name")
# Out:
# Enter Birth Year 1999
# Enter your name ahmad

# %%
if birthDate > 1900 and  birthDate < 2026:
    print(2026-birthDate)
    print(name)
else:
    print("Invalid Birth Year")
# Out:
# 27
# ahmad
