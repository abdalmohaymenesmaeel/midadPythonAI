# %%
lst=[]

# %%
lst.append(10)
lst
# Out:
# [10]

# %%
lst.insert(20,15)

# %%
lst
# Out:
# [10, 15]

# %%
lst2=[2,2]
lst3=lst2+lst

# %%
lst3
# Out:
# [2, 2, 10, 15]

# %%
lst.extend([7,7])

# %%
lst
# Out:
# [10, 15, 7, 7]

# %%
lst.extend([2,3,4])
lst
# Out:
# [10, 15, 7, 7, 2, 3, 4]

# %% [markdown]
# [9, 10, 10, 10, 0, 15, 7, 7, [2, 3, 4]]
# [9, 10, 10, 10, 0, 15, 7, 7, [2, 3, 4],2,3,4]

# %%
x=lst.pop(0)

# %%
x
# Out:
# 9

# %%
index =0
while index < len(lst):
    print(lst[index])
    index+=1
# Out:
# 10
# 10
# 10
# 0
# 15
# 7
# 7
# [2, 3, 4]
# 2
# 3

# %%
for i in lst:
    print(i)
# Out:
# 10
# 10
# 10
# 0
# 15
# 7
# 7
# [2, 3, 4]
# 2
# 3

# %%
for i in range(0,len(lst)):
    print(i,lst[i])
# Out:
# 0 10
# 1 10
# 2 10
# 3 0
# 4 15
# 5 7
# 6 7
# 7 [2, 3, 4]
# 8 2
# 9 3

# %%
for i in lst:
    if i ==7:
        print("Exist")
        break
# Out:
# Exist

# %%
lst
# Out:
# [10, 15, 7, 7, 2, 3, 4]

# %%
for i in range(0,len(lst)):
    print(lst.pop())
# Out:
# 4
# 3
# 2
# 7
# 7
# 15
# 10

# %%
for i in range(0,4):
    print(lst.pop(0))
# Out:
# 10
# 15
# 7
# 7

# %%
lst
# Out:
# [2, 3, 4]

# %%
lst.clear()

# %%
lst
# Out:
# []

# %%
false="Any value"

# %%
lst=[1,2,3,4,True,false,"Welcome"]
lst
# Out:
# [1, 2, 3, 4, True, 'Any value', 'Welcome']

# %%
lst.index("Welcome")
# Out:
# 6

# %%
index=0
while index<len(lst):
    if lst[index]=="Welcome":
        print(index)
    index+=1
# Out:
# 6

# %%
lst
# Out:
# [1, 2, 3, 4, True, 'Any value', 'Welcome']

# %%
lst.extend([2,2,2])

# %%
lst
# Out:
# [1, 2, 3, 4, True, 'Any value', 'Welcome', 2, 2, 2, 2]

# %%
lst.count(2)
# Out:
# 5

# %%
lst=[3,3,6,7,9,2,15,1]

# %%
lst.sort(reverse=True)

# %%
lst.reverse()

# %%
lst
# Out:
# [1, 15, 2, 9, 7, 6, 3, 3]

# %%
nlst=sorted(lst)
nlst
# Out:
# [1, 2, 3, 3, 6, 7, 9, 15]

# %%
lst
# Out:
# [1, 15, 2, 9, 7, 6, 3, 3]

# %%
len(lst)
# Out:
# 8

# %%
max(lst)
# Out:
# 15

# %%
min(lst)
# Out:
# 1

# %%
sum(lst)
# Out:
# 46

# %%
lst=[[3,4,5],[4,3,2],100]

# %%
print(type(lst))
# Out:
# <class 'list'>

# %%
for sublist in lst:
    for j in sublist:
        print(j,end=" ")
    print()
# Out:
# 3 4 5
# 4 3 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[246], line 2
#       1 for sublist in lst:
# ----> 2     for j in sublist:
#       3         print(j,end=" ")
#       4     print()
#
# TypeError: 'int' object is not iterable

# %%
copy
shallow copy
deep copy

# %%
a=[1,2]
b=a
b
# Out:
# [1, 2]

# %%
b[0]=15
b
# Out:
# [15, 2]

# %%
a == b
# Out:
# True

# %%
b=a.copy()
b
# Out:
# [15, 2]

# %%
a
# Out:
# [15, 2]

# %%
a[0]=0
a
# Out:
# [0, 2]

# %%
b
# Out:
# [15, 2]

# %%
a=[100,[1,2]]
b=a.copy()
b[0]=55

# %%
a
# Out:
# [100, [1, 2]]

# %%
b
# Out:
# [55, [1, 2]]

# %%
a[1][0]=100
b
# Out:
# [55, [100, 2]]

# %%
a
# Out:
# [100, [100, 2]]

# %%
b
# Out:
# [55, [100, 2]]

# %%
b[1][0]=50

# %%
a
# Out:
# [100, [50, 2]]

# %%
import copy

# %%
d=copy.deepcopy(a)

# %%
d
# Out:
# [100, [50, 2]]

# %%
a
# Out:
# [100, [50, 2]]

# %%
d[0]=55
d[1][0]=55
d[1][1]=55
d
# Out:
# [55, [55, 55]]

# %%
a
# Out:
# [100, [50, 2]]

# %%
lst=[2,5,6,4,3,5,9]
# Out:
# 9

# %%
lst
# Out:
# [2, 5, 6, 4, 3, 5, 9]

# %%
#lst[start:end:step]
lst[2::]
# Out:
# [6, 4, 3, 5, 9]

# %%
lst[:len(lst)-2:]
# Out:
# [2, 5, 6, 4, 3]

# %%
lst
# Out:
# [2, 5, 6, 4, 3, 5, 9]

# %%
lst[::-1]
# Out:
# [9, 5, 3, 4, 6, 5, 2]

# %%
bt=[1,0,0,1,0,0,1]
if bt==bt[::-1]:
    print("true")
else:
    print("no")
# Out:
# true

# %%
lst
# Out:
# [2, 5, 6, 4, 3, 5, 9]

# %%
lst[-1:-4:-2]
# Out:
# [9, 3]

# %%
lst[-1:-4:-2][::-1][::-1][0]
# Out:
# 9

# %%
lst
# Out:
# [2, 5, 6, 4, 3, 5, 9]

# %%
lst[3]==lst[-4]
# Out:
# True

# %%
lst=[2,3,6,7,1,5,[7,8,1]]
lst[-1][-2::-1]
# Out:
# [8, 7]
