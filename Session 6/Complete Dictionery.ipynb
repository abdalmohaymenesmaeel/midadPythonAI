# %%
d1={"name":"ahmad","salary":200}

# %%
del(d1)

# %%
d1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 d1
#
# NameError: name 'd1' is not defined

# %%
d1={"name":"ahmad","salary":200}

# %%
del(d1["name"])

# %%
d1
# Out:
# {'salary': 200}

# %%
del(d1["name"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 del(d1["name"])
#
# KeyError: 'name'

# %%
d1={"name":"ahmad","salary":200,"BY":2001}

# %%
d1.pop("name")
# Out:
# 'ahmad'

# %%
d1
# Out:
# {'salary': 200, 'BY': 2001}

# %%
item=d1.pop("salary",None)

# %%
item
# Out:
# 200

# %%
item=d1.pop("salary",None)

# %%
item

# %%
d1={"name":"ahmad","salary":200,"BY":2001}
item=d1.popitem()
item
# Out:
# ('BY', 2001)

# %%
d1
# Out:
# {'name': 'ahmad', 'salary': 200}

# %%
d1.popitem()
d1.popitem()
d1.popitem()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 3
#       1 d1.popitem()
#       2 d1.popitem()
# ----> 3 d1.popitem()
#
# KeyError: 'popitem(): dictionary is empty'

# %%
#dict = hashtable +stack

# %%
d1.clear()

# %%
d1["name"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 d1["name"]
#
# KeyError: 'name'

# %%
d1
# Out:
# {}

# %%
d1["name"]="ahmad"
d1
# Out:
# {'name': 'ahmad'}

# %%
#clear
#fromkey
#get
#pop
#popitem
#setdefault
#update

# %%
d1={"name":"ahmad","salary":200,"BY":2001}
d1.keys()
# Out:
# dict_keys(['name', 'salary', 'BY'])

# %%
d1.values()
# Out:
# dict_values(['ahmad', 200, 2001])

# %%
d1.items()
# Out:
# dict_items([('name', 'ahmad'), ('salary', 200), ('BY', 2001)])

# %%
for i in d1.keys():
    print(i)
# Out:
# name
# salary
# BY

# %%
for i in d1.values():
    print(i)
# Out:
# ahmad
# 200
# 2001

# %%
for i in d1.items():
    print(i)
# Out:
# ('name', 'ahmad')
# ('salary', 200)
# ('BY', 2001)

# %%
for k,v in d1.items():
    print(k,v)
# Out:
# name ahmad
# salary 200
# BY 2001

# %%
d1={"name":"ahmad","salary":200}
d2=d1
d2["salary"]=300
d1
# Out:
# {'name': 'ahmad', 'salary': 300}

# %%
d1["name"]="abdalmohaymen"
d2
# Out:
# {'name': 'abdalmohaymen', 'salary': 300}

# %%
#shallow copy

# %%
d2={"name":"abdalmohaymen","salaries":[230,270,270,300,300]}

# %%
d3=d2.copy()

# %%
d2["name"]="hamza"

# %%
d3
# Out:
# {'name': 'abdalmohaymen', 'salaries': [230, 270, 270, 300, 300]}

# %%
d2["salaries"][1]=280
d2["salaries"][2]=280

# %%
d2
# Out:
# {'name': 'hamza', 'salaries': [230, 280, 280, 300, 300]}

# %%
d3
# Out:
# {'name': 'abdalmohaymen', 'salaries': [230, 280, 280, 300, 300]}

# %%
import copy

# %%
#deep copy
d4=copy.deepcopy(d2)

# %%
d2
# Out:
# {'name': 'hamza', 'salaries': [230, 280, 280, 300, 300]}

# %%
d4
# Out:
# {'name': 'hamza', 'salaries': [230, 280, 280, 300, 300]}

# %%
d2["salaries"][0]=250

# %%
d3
# Out:
# {'name': 'abdalmohaymen', 'salaries': [250, 280, 280, 300, 300]}

# %%
d4
# Out:
# {'name': 'hamza', 'salaries': [230, 280, 280, 300, 300]}

# %%
#mongoDB

# %%
[{"salaries":[{"month":1,"year":2025,"value":230},{}],{},{}]

# %%
#Dict Comprehension

# %%
numSquars={}

# %%
for i in range(1,20):
    numSquars[i]=i*i
numSquars
# Out:
# {1: 1,
#  2: 4,
#  3: 9,
#  4: 16,
#  5: 25,
#  6: 36,
#  7: 49,
#  8: 64,
#  9: 81,
#  10: 100,
#  11: 121,
#  12: 144,
#  13: 169,
#  14: 196,
#  15: 225,
#  16: 256,
#  17: 289,
#  18: 324,
#  19: 361}

# %%
dic={x:x*x for x in range(1,10)}
dic
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %%
st="Welcome in our session"
stwords={}
for i in st.split():
    #print(i)
    stwords[i]=len(i)
stwords
# Out:
# {'Welcome': 7, 'in': 2, 'our': 3, 'session': 7}

# %%
stwords1={i:len(i) for i in st.split() }
stwords1
# Out:
# {'Welcome': 7, 'in': 2, 'our': 3, 'session': 7}
